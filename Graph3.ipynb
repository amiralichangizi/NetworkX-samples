# %%
import networkx as nx

# %%
G=nx.petersen_graph()
nx.draw_networkx(G)
print(nx.info(G))
# Out:
# Graph named 'Petersen Graph' with 10 nodes and 15 edges

# %%
 list(G.degree())
# Out:
# [(0, 3),
#  (1, 3),
#  (2, 3),
#  (3, 3),
#  (4, 3),
#  (5, 3),
#  (6, 3),
#  (7, 3),
#  (8, 3),
#  (9, 3)]

# %%
print(nx.degree_histogram(G))
# Out:
# [0, 0, 0, 10]

# %%
list(nx.all_neighbors(G,2))
# Out:
# [1, 3, 7]

# %%
list(nx.non_neighbors(G,2))
# Out:
# [0, 4, 5, 6, 8, 9]

# %%
list(nx.common_neighbors(G,3,5))
# Out:
# [8]

# %%
G.add_node(11)

# %%
nx.draw_networkx(G)

# %%
list(nx.isolates(G))
# Out:
# [11]

# %%
nx.is_isolate(G,2)
# Out:
# False

# %%
nx.is_isolate(G,11)
# Out:
# True

# %%
G.add_edge(6,11)
G.add_edge(12,11)
G.add_edge(13,11)
G.add_edge(13,12)

# %%
nx.draw_networkx(G)

# %%
nx.has_bridges(G)
# Out:
# True

# %%
list(nx.bridges(G))
# Out:
# [(6, 11)]

# %%
l=[(5,7),(7,9)]
G.remove_edges_from(l)

# %%
nx.draw_networkx(G)

# %%
list(nx.bridges(G))
# Out:
# [(2, 7), (6, 11)]

# %%
G1=nx.DiGraph([(1,2),(2,3),(3,4),(1,4),(2,5)])
nx.draw_networkx(G1)

# %%
nx.descendants(G1,2)
# Out:
# {3, 4, 5}

# %%
nx.ancestors(G1,2)
# Out:
# {1}

# %%
nx.draw_networkx(G)
nx.is_eulerian(G)
# Out:
# False

# %%
G2=nx.petersen_graph()
nx.draw_networkx(G2)
nx.is_eulerian(G2)
# Out:
# False

# %%
G3=nx.complete_bipartite_graph(4,4)
nx.draw_networkx(G3)
nx.is_eulerian(G3)
list(nx.eulerian_circuit(G3))
# Out:
# [(0, 7),
#  (7, 3),
#  (3, 6),
#  (6, 2),
#  (2, 5),
#  (5, 3),
#  (3, 4),
#  (4, 2),
#  (2, 7),
#  (7, 1),
#  (1, 6),
#  (6, 0),
#  (0, 5),
#  (5, 1),
#  (1, 4),
#  (4, 0)]

# %%
nx.relabel_nodes(G3,{1:'first',2:'second',3:'third'}, copy=False)
nx.draw_networkx(G3)

# %%
G3_C=nx.complement(G3)
nx.draw_networkx(G3_C)

# %%
IG=nx.intersection(G3,G3_C)
nx.draw_networkx(IG)

# %%
H=nx.Graph([(1,2),(2,3),(1,3)])
nx.draw_networkx(H)

# %%
UG=nx.union(G3,H)
nx.draw_networkx(UG)

# %%
G1=nx.DiGraph([(1,2),(2,3),(3,4),(1,4),(2,5)])
nx.draw_networkx(G1)
G1.edges()
# Out:
# OutEdgeView([(1, 2), (1, 4), (2, 3), (2, 5), (3, 4)])

# %%
IG1=nx.reverse(G1)
nx.draw_networkx(IG1)
IG1.edges()
# Out:
# OutEdgeView([(2, 1), (3, 2), (4, 1), (4, 3), (5, 2)])

# %%
nx.is_frozen(G1)
# Out:
# False

# %%
G1=nx.freeze(G1)
nx.is_frozen(G1)
# Out:
# True

# %%
#G1.add_edge(3,4)

# %%
nx.draw_networkx(G)

# %%
nx.eccentricity(G,11)
# Out:
# 4

# %%
for j in G.nodes():
  print(j, nx.eccentricity(G,j))
# Out:
# 0 4
# 1 3
# 2 4
# 3 4
# 4 4
# 5 4
# 6 3
# 7 5
# 8 3
# 9 4
# 11 4
# 12 5
# 13 5

# %%
nx.radius(G)
# Out:
# 3

# %%
nx.diameter(G)
# Out:
# 5

# %%
nx.center(G)
# Out:
# [1, 6, 8]

# %%
nx.periphery(G)
# Out:
# [7, 12, 13]
